# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [2,3,4,10]

plt.title("Meu primeiro grafico no python") # Comando para criar o titulo no python

plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")

plt.plot(x, y)
plt.show()
