# %%
import matplotlib.pyplot as plt
x1 = [1, 3, 5, 7, 9]
y1 = [2, 5, 3, 12, 10]

x2 = [2, 4, 6, 8, 10]
y2 = [3, 1, 5, 9, 11]

plt.title("Segundo teste de Grafico de Barras") # Comando para criar o titulo no python

plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")

plt.bar(x1, y1, label = "Amostras 34")
plt.bar(x2, y2, label = "Amostras 22") 
plt.legend()

plt.show()
