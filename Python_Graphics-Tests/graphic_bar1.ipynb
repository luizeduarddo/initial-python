# %% [markdown]
# # Primeiro teste de gráfico em barras.
# ---
#
# Esse é meu primeiro teste com códigos de barras com apenas um eixo.

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [2,5,3,12]

plt.title("Grafico de Barras") 
plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")

plt.bar(x, y)
plt.show()
